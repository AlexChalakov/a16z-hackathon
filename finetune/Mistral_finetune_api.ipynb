# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexChalakov/a16z-hackathon/blob/main/Mistral_finetune_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fine tuning Mistral Large model
#
# (Notebook adapted from: https://docs.mistral.ai/capabilities/finetuning/)

# %%
# !pip install mistralai pandas
# Out:
# Requirement already satisfied: mistralai in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from mistralai) (0.2.0)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from mistralai) (0.27.2)
# Requirement already satisfied: jsonpath-python<2.0.0,>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from mistralai) (1.0.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from mistralai) (2.9.2)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.10/dist-packages (from mistralai) (2.8.2)
# Requirement already satisfied: typing-inspect<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from mistralai) (0.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil==2.8.2->mistralai) (1.16.0)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->mistralai) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->mistralai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->mistralai) (1.0.6)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->mistralai) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->mistralai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->mistralai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.9.0->mistralai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.9.0->mistralai) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.9.0->mistralai) (4.12.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<0.10.0,>=0.9.0->mistralai) (1.0.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<0.28.0,>=0.27.0->mistralai) (1.2.2)
# /bin/bash: line 1: brew: command not found

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import json

# %% [markdown]
# ## Prepare EmpatheticDiaglogues dataset
#
# https://dl.fbaipublicfiles.com/parlai/empatheticdialogues/empatheticdialogues.tar.gz

# %%
train_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Mistral AI hackathon/empatheticdialogues/train.csv')
valid_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Mistral AI hackathon/empatheticdialogues/valid.csv')
test_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Mistral AI hackathon/empatheticdialogues/test.csv')

# %%
train_df.head()
# Out:
#         conv_id utterance_idx      context  \
# 0  hit:0_conv:1             1  sentimental
# 1  hit:0_conv:1             2  sentimental
# 2  hit:0_conv:1             3  sentimental
# 3  hit:0_conv:1             4  sentimental
# 4  hit:0_conv:1             5  sentimental
#
#                                               prompt speaker_idx  \
# 0  I remember going to the fireworks with my best...           1
# 1  I remember going to the fireworks with my best...           0
# 2  I remember going to the fireworks with my best...           1
# 3  I remember going to the fireworks with my best...           0
# 4  I remember going to the fireworks with my best...           1
#
#                                            utterance     selfeval
# 0  I remember going to see the fireworks with my ...  5|5|5_2|2|5
# 1  Was this a friend you were in love with_comma_...  5|5|5_2|2|5
# 2                This was a best friend. I miss her.  5|5|5_2|2|5
# 3                                Where has she gone?  5|5|5_2|2|5
# 4                                 We no longer talk.  5|5|5_2|2|5

# %%
def replace_comma(text):
    return text.replace('_comma_', ',')

# %%
train_df = train_df.dropna()
valid_df = valid_df.dropna()
test_df = test_df.dropna()

# %%
train_df['utterance'] = train_df['utterance'].apply(replace_comma)
valid_df['utterance'] = valid_df['utterance'].apply(replace_comma)
test_df['utterance'] = test_df['utterance'].apply(replace_comma)
# Out:
# <ipython-input-34-7dffcdb68699>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['utterance'] = test_df['utterance'].apply(replace_comma)

# %%
replace_comma('Here is a_comma_ comma')
# Out:
# 'Here is a, comma'

# %%
def convert_to_jsonl(df):
    conversations = []
    current_conv_id = None
    current_messages = []
    user_index = None

    for _, row in df.iterrows():
        conv_id = row['conv_id']
        utterance = row['utterance']
        speaker_idx = row['speaker_idx']

        # Determine role: alternate turns represent user and assistant
        if current_conv_id != conv_id:
            # Start a new conversation
            if len(current_messages) > 0:
                conversations.append({"messages": current_messages})

            current_conv_id = conv_id
            current_messages = []
            user_index = speaker_idx

        # Assign roles alternately based on speaker index sequence
        role = "user" if speaker_idx == user_index else "assistant"

        # Append the message to current conversation
        current_messages.append({"role": role, "content": utterance})


    return conversations

# %%
train_df_json = convert_to_jsonl(train_df)
valid_df_json = convert_to_jsonl(valid_df)
test_df_json = convert_to_jsonl(test_df)

# %%
test_df_json
# Out:
# [{'messages': [{'role': 'user',
#     'content': 'Yeah about 10 years ago I had a horrifying experience. It was 100% their fault but they hit the water barrels and survived. They had no injuries but they almost ran me off the road.'},
#    {'role': 'assistant', 'content': 'Did you suffer any injuries?'},
#    {'role': 'user',
#     'content': "No I wasn't hit. It turned out they were drunk. I felt guilty but realized it was his fault."},
#    {'role': 'assistant',
#     'content': "Why did you feel guilty? People really shouldn't drive drunk."},
#    {'role': 'user',
#     'content': "I don't know I was new to driving and hadn't experienced anything like that. I felt like my horn made him swerve into the water barrels."}]},
#  {'messages': [{'role': 'user',
#     'content': 'Well, can you tell me about your experience? I think we swapped places'},
#    {'role': 'assistant',
#     'content': 'Yeah i wanted to tell you about the time i was hit by a drunk driver im so happy to still be alive after that experience'},
#    {'role': 'user',
#     'content': "Oh my goodness, that's very scary! I hope you are okay now and the drunk driver was punished for his actions?"},
#    {'role': 'assistant',
#     'content': 'Yeah he was punished hes in jail still'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I there, dont know what to do, jst broke up with my girlfirned, we were 8 years together'},
#    {'role': 'assistant',
#     'content': 'sorry to hear! do you have any idea about the break up? did you think about it ?'},
#    {'role': 'user',
#     'content': 'Yes we decided together with our minds, and know i come home and feel so distant from the world'},
#    {'role': 'assistant',
#     'content': "sorry again! hope you'll get relief from this sadness. Please concentrate on your interests to divert your mind from this."}]},
#  {'messages': [{'role': 'user',
#     'content': "I couldn't wait to go to the concert."},
#    {'role': 'assistant', 'content': 'Which Concert?'},
#    {'role': 'user',
#     'content': 'The U2 concert. Tickets were really expensive and I never thought we would be able to go, but somehow we did!!!'},
#    {'role': 'assistant',
#     'content': "Wow, that's awesome! I have never been to an actual concert."}]},
#  {'messages': [{'role': 'user',
#     'content': "I'm so sad because i've read an article about a newborn girl who died because her parents didn't believe in medication and doctors"},
#    {'role': 'assistant',
#     'content': 'Ugh, those articles always get me too... :( What was wrong with her? '},
#    {'role': 'user',
#     'content': 'she was born premature at home, she had hard time breathing on her own but instead of taking her to the doctor parents were just praying'},
#    {'role': 'assistant',
#     'content': 'Jeez! Its so unfortunate... very sad really. '},
#    {'role': 'user',
#     'content': 'yes! And i do believe in God and prayers but goodness gracious please take your children to the hospital and let God heal them THROUGH doctors'}]},
#  {'messages': [{'role': 'user',
#     'content': "so my friend's baby fell down and scraped his knee yesterday and i was trying so hard to cheer him up"},
#    {'role': 'assistant', 'content': 'That is nice of you. What did you do?'},
#    {'role': 'user', 'content': 'i was singing nursery songs :)'},
#    {'role': 'assistant', 'content': 'Which one?'},
#    {'role': 'user', 'content': 'If you happy and you know it :)'}]},
#  {'messages': [{'role': 'user',
#     'content': "my husband lost a job but i'm hoping he can find a full time job soon"},
#    {'role': 'assistant', 'content': 'He will, I have faith.'},
#    {'role': 'user', 'content': 'thank you so much!'},
#    {'role': 'assistant',
#     'content': 'No problem. What kind of work does he do?'},
#    {'role': 'user', 'content': 'he is an armed guard'}]},
#  {'messages': [{'role': 'user',
#     'content': 'i just moved to this neighborhood and some dumb criminals shot one of my neighbors and ran into the woods! '},
#    {'role': 'assistant', 'content': 'Thats not good. Do you own a gun?'},
#    {'role': 'user', 'content': 'I do! I want to be able to protect my son'},
#    {'role': 'assistant', 'content': 'That is always number one goal.'}]},
#  {'messages': [{'role': 'user',
#     'content': "i'm so excited because i'm finally going to visit my parents next month! I didn't see them for 3 years"},
#    {'role': 'assistant', 'content': '3 years is a long time. How come?'},
#    {'role': 'user',
#     'content': 'I moved to the US and they stayed in my homecountry'},
#    {'role': 'assistant', 'content': 'Oh I see. They must miss you, too.'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I was very angry when a co worker lied about a car accident to get out of working July 4th. I covered his shift till midnight and he was lying about the accident'},
#    {'role': 'assistant', 'content': "That isn't very nice."},
#    {'role': 'user',
#     'content': 'Yeah he got caught in someones pics on Facebook. Never lie and then go out with people who like to take pictures.'},
#    {'role': 'assistant', 'content': 'Yes. I do not have a Facebook.'},
#    {'role': 'user',
#     'content': "Good idea. i don't like social media that much. It can get you in to trouble fast, even when expressing your opinions."}]},
#  {'messages': [{'role': 'user',
#     'content': 'So yeah i drove 2 hours to get to wallmart. with 299 in my wallet as advertised, and the real price of the tv was 399 usd. what a bummer'},
#    {'role': 'assistant', 'content': 'Thats horrible.'},
#    {'role': 'user',
#     'content': 'Yeah i had my hopes reall high and then i left empty handed, such a terrible feeling!'},
#    {'role': 'assistant', 'content': 'Yes I do not like walmart.'},
#    {'role': 'user',
#     'content': 'Yes, i guess walmart and the rest of false advertisement in the US, the look in my daugther eyes when i came home empty handed'}]},
#  {'messages': [{'role': 'user',
#     'content': "My friend's boyfriend recently made a pass at me. I'm married, and I also am really good friend's with his girlfriend so I felt really bad. I made sure he knew I was loyal and honest to both!"},
#    {'role': 'assistant', 'content': 'Thats horrible. Did you tell on him?'},
#    {'role': 'user',
#     'content': "I struggled with it, but my friend was in a really bad spot, with no income and raising her grandchild, he was the financial supporter. So, I didn't tell her, as I knew it would really hurt her in several ways, plus she really loves him!"},
#    {'role': 'assistant', 'content': 'Thats a tough situation.'}]},
#  {'messages': [{'role': 'user',
#     'content': "my baby is sleeping. it's so peaceful and quiet in this house"},
#    {'role': 'assistant',
#     'content': "I guess it makes you appreciate things you used to take for granted, lol. But it doesn't last forever and is worth it. "},
#    {'role': 'user', 'content': 'i totally agree with you!'},
#    {'role': 'assistant',
#     'content': "That's a full time job raising a human"}]},
#  {'messages': [{'role': 'user',
#     'content': 'hi, i feel so lonely sometimes because all my friends live in a different country'},
#    {'role': 'assistant',
#     'content': "Oh, I'm sure you are lonely. Maybe you can join some kind of club that lets you meet new friends?"},
#    {'role': 'user',
#     'content': 'i was thinking about it! I wanted to join a group for local moms'},
#    {'role': 'assistant',
#     'content': "That's a good idea! This way you can also meet friends for yourself, but also maybe meet new friend's for your children to hang out with while you do with their moms!"}]},
#  {'messages': [{'role': 'user',
#     'content': "I have a friend that has a child that is unruly and does bad things. One day at our home, he grabbed a game and sat on it, instantly breaking it! It was expensive and this really irked me, especially because she doesn't discipline him when he does bad things."},
#    {'role': 'assistant',
#     'content': "oh man. i'm all about discipline! I don't like spoiled bratty kids"},
#    {'role': 'user',
#     'content': "Me either! I have two of my own children, and I would have never let them get away with that kind of behavior when they were his age. I just don't understand those kind of parents@!"},
#    {'role': 'assistant',
#     'content': "yes, i've heard some parents don't ever say no to their kids. makes no sense"}]},
#  {'messages': [{'role': 'user',
#     'content': "I'm so scared of bugs! i found one in my hair yesterday and almost died"},
#    {'role': 'assistant', 'content': 'ok'},
#    {'role': 'user',
#     'content': 'Ugh I hate bugs with a passion, they are so creepy'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I recently spoke with my ex-girlfriend on the phone. The conversation went pretty well, and it reminded me of my past experiences with her.'},
#    {'role': 'assistant',
#     'content': 'Did things end amicably? I hope everything is good now!'},
#    {'role': 'user',
#     'content': "Yes, they ended somewhat well, but there were tense moments. I am glad she's doing well, but I miss her."},
#    {'role': 'assistant',
#     'content': 'I understand that, I hope things work out well for you both in the end!'},
#    {'role': 'user', 'content': 'Thank you! That means a lot.'}]},
#  {'messages': [{'role': 'user',
#     'content': 'One of the times I remember feeling the most blissed out in life was right after the birth of my first child.'},
#    {'role': 'assistant',
#     'content': 'That is a very blessed day. It is something you will never forget.'},
#    {'role': 'user',
#     'content': 'Obviously there are the demands of a new child -- but that feeling of finally meeting someone you waited so long for, and the love surrounding the whole situation. Truly something to remember.'},
#    {'role': 'assistant',
#     'content': "Yes, I couldn't agree more. It is remarkable how your feeling suddenly change."}]},
#  {'messages': [{'role': 'user',
#     'content': 'Have you ever been in a situation when payment of some kind has come through *just* in the nick of time?! Talk about gratitude!'},
#    {'role': 'assistant',
#     'content': 'I bet that must have been nerve wracking until it happened.'},
#    {'role': 'user',
#     'content': "Absolutely. You go from scared and desperate to grateful and optimistic in one quick moment! It's not a situation I wish to be in again."},
#    {'role': 'assistant',
#     'content': "Oh I'm sure. I would not like to be in a situation like that. Good thing everything worked out for you."}]},
#  {'messages': [{'role': 'user',
#     'content': 'Im so grateful for my family due to an incident with my friend'},
#    {'role': 'assistant',
#     'content': 'Oh really? What happened with your family and friend then?'},
#    {'role': 'user',
#     'content': 'My friend lost her parents and siblings in a fire and their family was very close to mine. So seeing her go through the grief made me realize how thankful I should be '},
#    {'role': 'assistant',
#     'content': "Oh wow, that's awful. Stuff like that really teaches you to appreciate what you've got and to not take it for granted."},
#    {'role': 'user',
#     'content': 'Yes definitely. Never take anything for granted as you never know when it will be taken away from you'}]},
#  {'messages': [{'role': 'user',
#     'content': "I'm a big believer in listening to your gut. Sometimes I might wonder where my intuition is leading me, but it always seems to be spot on."},
#    {'role': 'assistant', 'content': 'I agree, someimes we just know'},
#    {'role': 'user',
#     'content': 'It is a "knowing" -- and a flowing! When something is right, it just feels easier to go with it -- like you\'re being led, even if you might not fully know to where.'},
#    {'role': 'assistant', 'content': 'exactly, i get that entirely!'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I couldnt celebrate my 18th birthday as I had exams during the time and I felt terrible for it. But my friends threw a surprise party for me and it was the best! '},
#    {'role': 'assistant',
#     'content': "That's great! How did they surprise you?"},
#    {'role': 'user',
#     'content': 'I was studying in my bedroom for a couple of hours straight with headphones on and then my mom called me to the living room for dinner and when I went out the whole place was decorated and everyone was there'},
#    {'role': 'assistant',
#     'content': 'That is so sweet of them, I hope you enjoyed it!'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I feel lonely sometimes cause I live in a house with 5 girls and all of them have boyfriends and sometimes they are all hanging out with their significant others and I feel lonely'},
#    {'role': 'assistant',
#     'content': "Awww, That sucks man. Hopefully they don't say mean things to you about being lonely."},
#    {'role': 'user',
#     'content': 'Sometimes they joke about it and obviously I make it look like its totally fine cause I dont want to give them the impression that I am lonely but it does hurt sometimes'},
#    {'role': 'assistant',
#     'content': 'Well i used to be lonely a lot but i eventually found someone. I think you will too.'}]},
#  {'messages': [{'role': 'user',
#     'content': "As silly as it sounds, I was so surprised at how different my two kids were as babies. You're reminded that they're wired with their own personalities from the git-go."},
#    {'role': 'assistant',
#     'content': 'Yeah that is always odd to me, before they can talk they are already unique!'},
#    {'role': 'user',
#     'content': 'One was pacifier, one was fingers. One wanted to co-sleep, one liked her space. One liked facing *out* in the Baby Bjorn carrier, one liked cocooning in a sling!'},
#    {'role': 'assistant',
#     'content': 'That is how it goes, sometimes you can just figure them out immediately'}]},
#  {'messages': [{'role': 'user',
#     'content': 'The other day I had a deep craving for Chik-Fil-A.'},
#    {'role': 'assistant',
#     'content': 'I understand that one,they are my favorite place to eat'},
#    {'role': 'user',
#     'content': "Mine too. So I drive there and pull in the parking lot and it's completely empty. I then realized it was Sunday."},
#    {'role': 'assistant',
#     'content': 'That has happened to me too many times to count'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I visited an orphan once and it was such a surreal moment. It made me realise how thankful I should be for a family'},
#    {'role': 'assistant',
#     'content': 'That must have been and intense and emotional moment for you.'},
#    {'role': 'user',
#     'content': 'Yes it definitely was. I went with intentions to teach the kid a few things but I ended up learning lots more from him '},
#    {'role': 'assistant',
#     'content': 'Uau, what a surreal moment.I always believe kids have a lot to teach us.'}]},
#  {'messages': [{'role': 'user',
#     'content': "My oldest and my husband have always had a rough relationship. I've got to believe that as she gets older, it will get better!"},
#    {'role': 'assistant',
#     'content': "I'm sure it will! I didn't get along with my dad until i became an adult."},
#    {'role': 'user',
#     'content': "That's always good to hear. But in the moment -- argh, my *heart*. How did your mom maneuver the differences between y'all? Did that wear on her?"},
#    {'role': 'assistant',
#     'content': 'Yes it did. I believe she just waited it out and tried to neutralize the conversation when we were together. '},
#    {'role': 'user',
#     'content': "But in the meantime -- the unspoken strain is NOT fun. But I'm glad to hear about a happy ending -- thank you for that!"}]},
#  {'messages': [{'role': 'user',
#     'content': "I can still look back with shame at the way I treated a girl in sixth grade. I wasn't as bad as others, but that doesn't make me feel any better."},
#    {'role': 'assistant', 'content': 'Where you not secure in your self?'},
#    {'role': 'user',
#     'content': 'Well, like a lot of 6th graders I was aware of *not* wanting to be an outcast for any reason. And unfortunately, she was. As an adult of course, my heart squeezes for *all* the kids we were!'},
#    {'role': 'assistant',
#     'content': 'You can track her down to say sorry, or would that be creepy?'},
#    {'role': 'user',
#     'content': 'Unfortunately, she died. I only found out when Facebook first came out, and her brother and I "friended" one another.'},
#    {'role': 'assistant',
#     'content': "Wow, so your going to take being a bad person to the grave. Maybe you'll see her in the next life?"}]},
#  {'messages': [{'role': 'user',
#     'content': "I'm currently working for someone that is *such* a great example of a leader! It makes going into work inspiring every day / every way."},
#    {'role': 'assistant',
#     'content': 'Lucky you! That is rare. Maybe one day people will think of you like that?'},
#    {'role': 'user',
#     'content': "That's a very kind statement, and certainly what I would strive for. And it's the rarity that *inspires* me. That should be the norm, not the exception! THAT'S what I'd like to inspire in people. How about you?"},
#    {'role': 'assistant',
#     'content': 'I have something totally different. My boss is clueless to the world and have no business being a leader. '},
#    {'role': 'user',
#     'content': 'That is soul-sapping. What do you do to inspire yourself, and not let that kind of behavior drag you down?'},
#    {'role': 'assistant',
#     'content': "Well I've been in the business all my life and have worked for some great people. So I pull from what I learned from them."}]},
#  {'messages': [{'role': 'user',
#     'content': "My friend's baby has grown so much since the last time I had seen her!"},
#    {'role': 'assistant',
#     'content': "It's crazy how quickly kiddos grow! Even in a few weeks time! Do you see your friend and her baby often?"},
#    {'role': 'user',
#     'content': "It had been about 8 weeks - I don't get out her way often, even though we live 30 minutes away."},
#    {'role': 'assistant',
#     'content': "That is how life goes! Different schedules and demands -- I'm sure she's so thrilled when she *does* get to see you!"},
#    {'role': 'user',
#     'content': "Yes!  I got to be 'auntie' for a bit and help change her and get her fed and down for a nap while my friend had a chance to toss laundry in the wash.  It was a good day for everyone!"}]},
#  {'messages': [{'role': 'user',
#     'content': 'Running my first (and maybe only!) marathon felt like *such* a huge accomplishment!'},
#    {'role': 'assistant',
#     'content': "Wow, that is an amazing accomplishment!  Congratulations!  You gotta be feeling like you're on top of the world after that!"},
#    {'role': 'user',
#     'content': 'Ah, it was the best! Plus it helped that I purposely chose an amazing destination in which to run it -- it was the Venice Marathon!'},
#    {'role': 'assistant',
#     'content': 'My first thought was "California" but then there\'s Venice [Italy] and then either way, that\'s an amazing destination!'},
#    {'role': 'user',
#     'content': 'We were living overseas at the times -- the most impressive part was crossing the Grand Canal over a pontoon of boats to finish the marathon ;-)'},
#    {'role': 'assistant',
#     'content': 'Oh, wow.  Not only to be able to do all the running but to view the scenery!'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I recently found out that a person I very much intimately admired did not feel the same way for me. I was pretty surprised.'},
#    {'role': 'assistant',
#     'content': "I'm sorry to hear that! How did you find out? "},
#    {'role': 'user',
#     'content': 'She just started treating me differently all of a sudden. And now she is going to be moving away soon.'},
#    {'role': 'assistant',
#     'content': "That's a real bummer, but as they say, there are plenty of fish in the sea!"}]},
#  {'messages': [{'role': 'user',
#     'content': "I'm always appalled when I see bullying in action -- whether it's on a playground or political stage -- not much makes me angrier."},
#    {'role': 'assistant', 'content': 'I feel the same way.'},
#    {'role': 'user',
#     'content': "How do you channel the anger? Obviously, it too easily turns into the same kind of negative emotion I'm upset about -- so that can feel hypocritical!"},
#    {'role': 'assistant',
#     'content': 'I practice boxing. I love to punch the sandbags.It is very therapeutic.'},
#    {'role': 'user',
#     'content': "Are you ever tempted to put anyone's face on the punching bag?! Ha! (Kidding/not kidding!)"}]},
#  {'messages': [{'role': 'user',
#     'content': "One morning my mother came to my house to pick my daughter up for school and told me she saw my daughter's cat on the road and he had been hit. I had to tell my daughter about the loss of her beloved pet."},
#    {'role': 'assistant',
#     'content': 'Oh no that is terrible!  How did your daughter take it?'},
#    {'role': 'user',
#     'content': "She was around 11, so she took it very hard. I went ahead and let her stay home from school, as I knew she wouldn't do well that day."},
#    {'role': 'assistant',
#     'content': 'Oh poor thing.  I hope she is doing better now.  Losing a pet is extremely hard!'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I was soooo excited to take our kids to Disneyland for the first time!'},
#    {'role': 'assistant',
#     'content': 'ooo they are gonna love it, just its expensive, I remember when it was only $20 to get in.'},
#    {'role': 'user',
#     'content': 'Same! I was excited because I grew up going there. My grandparents lived in Tucson, and we would spend the summers with them -- the most exciting part being our drive to Disneyland each year!'},
#    {'role': 'assistant',
#     'content': 'Which one are you going to California or Florida ?'},
#    {'role': 'user',
#     'content': "California! Old school ;-) They've kept so much of the original, while adding lots of new attractions."}]},
#  {'messages': [{'role': 'user',
#     'content': 'I recently spoke to my father for the first time in years. It reminded me of my childhood and the distant past.'},
#    {'role': 'assistant',
#     'content': 'Cool.  Somethings never change.  What did you reflect upon?'},
#    {'role': 'user',
#     'content': 'We spoke about our recent lives. Apparently he is in the market for a new car.'},
#    {'role': 'assistant',
#     'content': 'Yeah, I miss my dad.  He died several years ago.  What kind of car is he looking for?'}]},
#  {'messages': [{'role': 'user',
#     'content': 'Do you like to organize your house.  My mother-in-law recently surprised me recently with some organizing stuff b/c she knows how much I love it!'},
#    {'role': 'assistant',
#     'content': "I'm trying to get into it. we have our first baby on the way and need to reorganize everything. Do you have tips? "},
#    {'role': 'user',
#     'content': 'Labels and Bins can be your best friend!  Especially with a new baby.  '},
#    {'role': 'assistant',
#     'content': "My big thing is i'm like O' I may need that leave it out of the tote box. Before I know it I have more stuff laying around then when I started."}]},
#  {'messages': [{'role': 'user',
#     'content': "I find it odd -- and annoying -- when people don't respond to or even acknowledge emails."},
#    {'role': 'assistant',
#     'content': "Well, sometimes people are busy and don't have the time to check emails"},
#    {'role': 'user',
#     'content': "It would be great if there was a way we could all tell the best way to reach someone -- I know some people prefer texts to emails -- but if you're in a work situation, how do you ensure communication?"},
#    {'role': 'assistant',
#     'content': 'Text and emails are still the best option., until a nw way is created.'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I recently had a big argument with my sister. We both got very upset and angry at each other.'},
#    {'role': 'assistant',
#     'content': "Isn't that what sisters are for?  What were you guys upset about?"},
#    {'role': 'user',
#     'content': "I'm not so sure. We just had a discussion that heated and became an argument with tempers flying."},
#    {'role': 'assistant',
#     'content': 'Maybe once you feel like you can bring it up again, you can try to approach the topic from another angle.'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I felt most lonely when we first moved overseas, my husband then had to travel out of *that* country for business -- AND I had a new baby!'},
#    {'role': 'assistant',
#     'content': 'Congratulations! Where did you travel from and where did you end up?'},
#    {'role': 'user',
#     'content': 'From Santa Fe to Hong Kong -- ultimately a fantastic adventure. And I ended up with a wonderful group of friends. Expats bond quickly!'},
#    {'role': 'assistant',
#     'content': 'That must have been quite the culture shock, glad it all worked out though!'}]},
#  {'messages': [{'role': 'user',
#     'content': 'One of the saddest things to me is when people underestimate what they can do and/or are capable of.'},
#    {'role': 'assistant',
#     'content': "I know, that actually happens to me sometimes! Last year I didn't get accepted into this fellowship and for a couple of weeks I was underestimating myself a lot."},
#    {'role': 'user',
#     'content': "That's perfectly natural. You sound like the kind of person, though, that quickly regained their bearings. Disappointments like that usually come with some *good* lessons."},
#    {'role': 'assistant',
#     'content': "Yea for sure, I definitely learned that sometimes life just works in a funny way. When's the last time you have been really disappointed? "}]},
#  {'messages': [{'role': 'user',
#     'content': 'Once my husband asked me not to tell my mom that he was busy that day when she needed his help but I told her anyway.  I really felt bad b/c he got pretty upset with me.'},
#    {'role': 'assistant',
#     'content': 'I totally understand why he was mad. Why did you tell her?'},
#    {'role': 'user',
#     'content': "Yeah thats a good question.  I totally deserved him being mad.  I just felt bad for him b/c he was so busy that day and I didn't want him to have one more thing on his plate I guess"},
#    {'role': 'assistant',
#     'content': 'I guess he wanted to be available if she needed him.'}]},
#  {'messages': [{'role': 'user',
#     'content': 'There was a back neighbor that called my 10 year old son a ugly name one time, simply because he entered her yard slightly when he rode around the corner.!'},
#    {'role': 'assistant',
#     'content': 'What is a back neighbor? And that is crazy!'},
#    {'role': 'user',
#     'content': "Yes, she lived several house back and she didn't know me, until after she did that! She knew me then, but after I talked to her, she apologized to both of us. "},
#    {'role': 'assistant', 'content': "Oh my! I'm glad she apologized!"}]},
#  {'messages': [{'role': 'user',
#     'content': "Too often, it's a health scare that makes us value health. It inspires me to try and do something to keep healthy every day."},
#    {'role': 'assistant',
#     'content': 'I understand. I am think the same thing. What is your health issue?'},
#    {'role': 'user',
#     'content': "Happily, I don't have one! It's more seeing family and friends and the situations they're in. Not everything can be helped -- but there are some things we can all do to take care of ourselves, you know?"},
#    {'role': 'assistant', 'content': 'Yes, we should try to yourself heathy'}]},
#  {'messages': [{'role': 'user',
#     'content': "Every time I look through older photos of my children, I'm taken right back to the time they were that size, and what we were doing! It's a bittersweet feeling, for sure."},
#    {'role': 'assistant',
#     'content': 'Oh, it sure is, I feel the same way. They grow up so fast! '},
#    {'role': 'user', 'content': 'Are your kids adults now?'},
#    {'role': 'assistant',
#     'content': 'One of them is! I have an 18 year old and a 12 year old.'},
#    {'role': 'user',
#     'content': "I have an 18 year old as well -- I don't know about you, but it's hard to consider her an adult sometimes!"}]},
#  {'messages': [{'role': 'user',
#     'content': 'I have a hard time having confidence in myself but when I got married and I had my hair and makeup done I felt like I was beautiful!  I had so much confidence in myself that day and it was great!'},
#    {'role': 'assistant',
#     'content': 'I bet you were beautiful on that day. :) I hope that confidence has carried on since then!'},
#    {'role': 'user',
#     'content': "I really try but it's hard to replicate that day for sure."},
#    {'role': 'assistant',
#     'content': 'It would be hard to replicate that day for sure, but I bet you have a lot to be confident about. You got this!'}]},
#  {'messages': [{'role': 'user',
#     'content': 'My husband and I both work for ourselves -- a blessing and a curse at times, since it can be tough to determine a "regular" income.'},
#    {'role': 'assistant',
#     'content': "I bet it's tough. A regular income is nice but the freedom you get from working for yourselfs is better. "},
#    {'role': 'user',
#     'content': "We found a pretty good balance in that I have a part-time job that I *love* -- and that comes with benefits like insurance. That's a big worry addressed, right there."},
#    {'role': 'assistant',
#     'content': 'Your so lucky. Insurance is my number one worry every month. '},
#    {'role': 'user',
#     'content': 'I am sorry, because I absolutely know that concern. I truly hope you find a resolution to that.'}]},
#  {'messages': [{'role': 'user',
#     'content': "I met up with an old flame recently, didn't go how I expected"},
#    {'role': 'assistant', 'content': "Oh ya? What happened?? I'm intrigued"},
#    {'role': 'user',
#     'content': 'Well, right after she gave me a big hug, she introduced me to her new boyfriend.'},
#    {'role': 'assistant',
#     'content': 'Woah plot twist. She brought him along to meet you? '},
#    {'role': 'user',
#     'content': 'I know right! No warning or anything. He turned out to be a nice guy, but I thought it was a little misleading on her part.'}]},
#  {'messages': [{'role': 'user',
#     'content': "My family and I are going on vacation in a few weeks. We rented a largo beachfront condo and I can't wait!"},
#    {'role': 'assistant',
#     'content': 'OH I love the beach!!  Which beach are you going to go to?'},
#    {'role': 'user',
#     'content': 'We are going to be staying at Miramar Beach in Florida, about an  hour Panama City Beach. The view is amazing from our balcony and we are so ready!'},
#    {'role': 'assistant',
#     'content': "PCB is where we always go! If you want to drive a little bit, go to HUNTS in PCB - it's off the beaten path but THE best seafood and prices - just go early (like 4oclock) for dinner or you won't get in!!"}]},
#  {'messages': [{'role': 'user',
#     'content': 'I was supposed to go for brunch with my friend Maria the other day. At least that was the plan.'},
#    {'role': 'assistant', 'content': "Why didn't you go?"},
#    {'role': 'user',
#     'content': "Well, we had initially agreed to meet at 11. Wouldn't you know it, she didn't end up returning my text until 3PM!"},
#    {'role': 'assistant',
#     'content': 'Is she always a flake? Maybe time for a new friend?'}]},
#  {'messages': [{'role': 'user',
#     'content': 'Me and my mom were at this grocery store recently and this guy started following us outside the store and then again inside the store it was so scary!'},
#    {'role': 'assistant', 'content': 'Did he do anything to you and your mom?'},
#    {'role': 'user',
#     'content': 'Well I knew he was following us and so I asked the manager to walk us out to the car and when he did we saw the guy come out again from between the two buildings b/c he was waiting on us.  so scary!'},
#    {'role': 'assistant', 'content': 'I am glad that nothing happened.'}]},
#  {'messages': [{'role': 'user',
#     'content': 'Did I tell you what happened with Li the other night? Boy do I feel dumb.'},
#    {'role': 'assistant', 'content': "No, you didn't tell me! What happened?"},
#    {'role': 'user',
#     'content': "She's 45 minutes late to our anniversary dinner. I don't know what happened to me but I called and left an angry message. Turns out, she had gotten T-boned at an intersection and was talking to the Police Officer when I called!"},
#    {'role': 'assistant',
#     'content': "Oh no! Is she okay?! Don't beat yourself up too much, you couldn't have ever imagined that she had been in an accident."}]},
#  {'messages': [{'role': 'user',
#     'content': "Ugh! I looked like such a fool at my girlfriend's work party! "},
#    {'role': 'assistant', 'content': 'What happened?'},
#    {'role': 'user',
#     'content': "Well, I ended up having way too much to drink. One of her co-workers had a bottle of Fireball (gross I KNOW) and was making everybody do shots. I didn't want to look foolish, so I had... well too many."},
#    {'role': 'assistant', 'content': 'I love Fireball.'}]},
#  {'messages': [{'role': 'user',
#     'content': 'Did I tell you what happened with the concert I was supposed to go to Saturday?'},
#    {'role': 'assistant', 'content': 'No, what happened?'},
#    {'role': 'user',
#     'content': "Well first of all, it wasn't just any concert - it was Jay-Z and Beyonce! AND IT GOT RAINED OUT! "},
#    {'role': 'assistant', 'content': 'Thats horrible. Will they reschedule?'}]},
#  {'messages': [{'role': 'user',
#     'content': 'You are never going to guess who was sleeping on the couch when I got home from New York...'},
#    {'role': 'assistant', 'content': 'Who, tell me!'},
#    {'role': 'user',
#     'content': 'My friend Benny! The one we all thought died in a monsoon in Thailand!'},
#    {'role': 'assistant', 'content': 'Wow, what happened?'}]},
#  {'messages': [{'role': 'user',
#     'content': "Recently, my husband came home from grocery shopping and had gifts for me for Mother's Day. He had a beautiful diamond ring and other lovely gifts, it was very unexpected!"},
#    {'role': 'assistant',
#     'content': "That is very nice gift. Did you bought anything for him for Father's day?"},
#    {'role': 'user',
#     'content': 'I did! I also gave him unexpected gifts and he was super happy. I was very touched by him being so thoughtful!'},
#    {'role': 'assistant', 'content': 'That is great.'}]},
#  {'messages': [{'role': 'user',
#     'content': "I know I shouldn't count my chicks before they hatch, but I'm feeling pretty good after that interview today!"},
#    {'role': 'assistant', 'content': 'Oh what job was the interview for?'},
#    {'role': 'user',
#     'content': 'This advertising company! The owner was there - you should have seen his face. My last freelance project was a real winner. Think I got it?'},
#    {'role': 'assistant', 'content': 'I think you got it man! Congratz!'}]},
#  {'messages': [{'role': 'user',
#     'content': 'Did I ever tell you about the time I "got taken hostage"?'},
#    {'role': 'assistant', 'content': 'oh my  are you really serious?'},
#    {'role': 'user',
#     'content': "As a heart attack. It was me and Big C at the World's Largest Pistachio. All of the sudden we hear gunshots, and DiDi's still in the car. We ran in the building, and he comes flying in after us. He never pointed the gun at us, and we ended up running away when he was distracted. It's too crazy - I can't make this up. Just glad to be alive!"},
#    {'role': 'assistant',
#     'content': 'I am very glad it has a happy ending. Sounds a bit scary'}]},
#  {'messages': [{'role': 'user',
#     'content': "I went to visit a friend one day and her boyfriend made a pass at me. He actually suddenly kissed me, as I was waiting for my friend to return. I couldn't believe his nerve!"},
#    {'role': 'assistant', 'content': 'Oh no, what did you do?'},
#    {'role': 'user',
#     'content': "I quietly pushed him away, as I didn't want my friend to hear. I was so shocked and upset, since he knew I wouldn't want to make a scene and took advantage."},
#    {'role': 'assistant', 'content': 'Did you ever tell your friend?  '}]},
#  {'messages': [{'role': 'user',
#     'content': "This past Friday night our refrigerator stopped cooling! We had to go the weekend without it, and of course had to deal with some unpleasant smells and throw away a large amount of food! It wasn't a fun weekend for us!"},
#    {'role': 'assistant',
#     'content': 'Oh no, I hate when that happens. I can sympathize with you because thats happen to me twice! Its okay in the winter time and you can sort of keep your food fresh but not during the summer'},
#    {'role': 'user',
#     'content': "Yes, and of course we tried to call and have someone come out, but to no avail! You don't realize how much you rely on things like that until they aren't working!"},
#    {'role': 'assistant',
#     'content': 'I wish refrigerators would have a warranty that replaced food when they went bad. '}]},
#  {'messages': [{'role': 'user',
#     'content': 'I felt pretty bad when I was having girl talk with my friend and we were talking about our partners. Her boyfriend had made a pass at me, but I never told her about it. '},
#    {'role': 'assistant',
#     'content': 'Wao, you must fell weird about it! what you thinki to do about it?'},
#    {'role': 'user',
#     'content': "I felt bad, but she wasn't working and taking care of her grandchild, and her boyfriend was the financial support. I knew it would really be hard on her if she found out, not to mention she really loves him."},
#    {'role': 'assistant',
#     'content': 'SUper tough situation, i think you should let her know, and let her decides next'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I was at the mall and hug my mom and said to her: Time to go Mommy! and i wasnt her, can you imagine my reaction to it?'},
#    {'role': 'assistant',
#     'content': "Oh, I'm sure you were embarrassed! But, maybe you can laugh about it now?"},
#    {'role': 'user',
#     'content': "Yes, totally but at the moment i felt like the stupidiest person on earth, didn't know were to hide! and my mom was watching"},
#    {'role': 'assistant',
#     'content': "Well, I'm sure mom had a laugh lol! I can imagine how you felt at the time though!"},
#    {'role': 'user',
#     'content': 'THe good thing about it, was the lady, she was laughing and later told me that it has happened to her childrens to, no worries!'}]},
#  {'messages': [{'role': 'user',
#     'content': "I am looking forward to going on vacation in a few weeks! We have a condo reserved on the beach, with fantastic ocean views. I'm ready!"},
#    {'role': 'assistant',
#     'content': 'Ah, that sounds fantastic! Which ocean will you be enjoying?'},
#    {'role': 'user',
#     'content': "Well, we are staying at Panama City Beach, so we're right there at the Gulf of Mexico."},
#    {'role': 'assistant',
#     'content': 'Sounds awesome! Do you have a beachside beverage or traditions that you enjoy? (Mine would be tequila + lime...very Jimmy Buffett ;-))'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I am definitely a proud parent of our 15 year old -- she was determined to work this summer, and even with us saying no one would hire her until 16 -- she found a job!'},
#    {'role': 'assistant',
#     'content': "Well, that's impressive! I can see why you are proud. Sounds like a hard working young lady!"},
#    {'role': 'user',
#     'content': "That, and she's enjoying the independence of having her own money. Remember that? Making money that you truly could use for your *pleasure* (and not just necessities ?! ;-))"},
#    {'role': 'assistant',
#     'content': 'Yes, I was the same way too! I started working two days after I turned 16 so I could have my own money too!'},
#    {'role': 'user',
#     'content': "Same! I was surprised 15 year olds *can* actually work during the summer. It's just finding an employer who knows those hours get cut WAY back once school starts."}]},
#  {'messages': [{'role': 'user',
#     'content': 'Okay, a silly pet peeve but one nonetheless -- when people just leave their grocery carts willy-nilly in the parking lot. No consideration for others or the people who work at the store!'},
#    {'role': 'assistant',
#     'content': 'Absolutely I agree I always try to not even bring cart unless I have too many too carry.'},
#    {'role': 'user',
#     'content': 'Me too. And I will always make sure to at *least* put it in one of those cart corrals, if not walk it back up to the store. Hey -- extra exercise ;-)'},
#    {'role': 'assistant',
#     'content': 'Yes me too Now if everyone would just take our lead lol'},
#    {'role': 'user',
#     'content': 'WE CAN SAVE THE WOOOOOOORLD!!!!! (lol indeed....!)'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I came home, and my wife showed me a picture in 4d of our future baby, my heart speeded so fast!'},
#    {'role': 'assistant',
#     'content': 'oh wow. Do you know whether it will be a boy or girl yet?'},
#    {'role': 'user',
#     'content': 'We choose to wait! but the amount of happiness in my body is tremendous! never felt this way before.'},
#    {'role': 'assistant', 'content': 'First time parent?'},
#    {'role': 'user',
#     'content': 'Yes, God willing the baby is going to be healthy in every way! can wait to ave the second'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I love being in the "flow" -- whether it\'s in speaking to a group of people or working to help facilitate meetings.'},
#    {'role': 'assistant', 'content': 'What kind of work do you do?'},
#    {'role': 'user',
#     'content': 'I work with different organizations on strengthening their culture, and I do large-scale visual notetaking (also known as graphic recording). Are you familiar with that at all? (Not unusual NOT to be!)'},
#    {'role': 'assistant',
#     'content': "Actually I'm not, but it sounds very interesting and by working with different organizations, I would imagine it's also exciting and new every day."},
#    {'role': 'user',
#     'content': "That's one of the huge benefits -- learning about many different industries and subjects!"}]},
#  {'messages': [{'role': 'user',
#     'content': 'I LOVE when leaders know that it actually *helps* them to be surrounded by strong people -- people they can learn from, that challenge them, and that in some ways could be considered "better".'},
#    {'role': 'assistant',
#     'content': 'I agree, its always nice to have people around you who are smarter in some areas'},
#    {'role': 'user',
#     'content': 'It\'s just too many leaders want "yes men" and/or people who feel non-threatening. It\'s a trap and a quick path to mediocrity, if not failure!'},
#    {'role': 'assistant',
#     'content': 'Yes men are definitely a bad idea when it comes to life and business'}]},
#  {'messages': [{'role': 'user',
#     'content': "I'll always remember the day I learned I was pregnant with our first child -- Halloween in Chicago, and we were with friends at the Shedd Aquarium! I've loved baby belugas since ;-)"},
#    {'role': 'assistant',
#     'content': 'Baby belugas are cute, but not as cute as your baby!'},
#    {'role': 'user',
#     'content': 'Ha! True that ;-) That\'s also the year that A Bug\'s Life came out, and we always thought of our young one as "Dot", the spunky little girl ant in the movie.'},
#    {'role': 'assistant',
#     'content': "That is so funny! I don't think she'll want to be compared to an ant when she gets older. You'll have to remind her."}]},
#  {'messages': [{'role': 'user',
#     'content': "This mother's day was amazing! I got so much more than expected and it was all so heartfelt"},
#    {'role': 'assistant',
#     'content': "That is great!!  Sometimes we mom's get a bit forgotten, so to have an entire day where we are just loved is such a great feeling."},
#    {'role': 'user',
#     'content': 'Yes, definitely! I actually cried a few times because of how much thought went into each gift and what was written in the cards '},
#    {'role': 'assistant',
#     'content': 'Those words are the things we cherish more than any other thing, I love it when my girls do that!'}]},
#  {'messages': [{'role': 'user',
#     'content': "THat's too bad. What do you think went wrong?"},
#    {'role': 'assistant', 'content': 'I am not sure, it was pretty random'},
#    {'role': 'user', 'content': 'Did they give you any feedback?'},
#    {'role': 'assistant', 'content': 'No, nothing at all'},
#    {'role': 'user',
#     'content': 'That is a shame, you need to learn from your mistakes.'},
#    {'role': 'assistant', 'content': 'I know'}]},
#  {'messages': [{'role': 'user',
#     'content': 'So my sister told us a couple weeks ago she was pregnant. Her and her husband are so excited. I hope they have an amazing 9 months and then an amazing time raising the baby.'},
#    {'role': 'assistant',
#     'content': 'That is exciting news!  I bet you were so surprised!'},
#    {'role': 'user',
#     'content': "I was very surprised. She didn't tell a single person they were trying for a baby. Just announced it on the 4th of July"},
#    {'role': 'assistant',
#     'content': 'Ha!  What a neat day to announce it - did they do any special kind of announcement?  I see so many videos of interesting and neat ways to make that announcement.'},
#    {'role': 'user',
#     'content': 'Yes, they put a picture of their sonogram on the tv and waited for someone to notice it. So exciting'}]},
#  {'messages': [{'role': 'user',
#     'content': 'Oh no, what did you do instead? Did you watch Netflix?'},
#    {'role': 'assistant',
#     'content': 'I do watch Netflix sometimes.  Do you watch?'},
#    {'role': 'user',
#     'content': 'Yes, I do. I recently watched the series "Dark." It\'s the German one.'},
#    {'role': 'assistant',
#     'content': "I haven't heard of that one.  What genre does it fall in?"},
#    {'role': 'user',
#     'content': "It's a supernatural mystery type. I won't spoil the twist."},
#    {'role': 'assistant', 'content': 'Sounds interesting!'},
#    {'role': 'user',
#     'content': 'It was fantastic, a lot of people have been comparing it to Stranger Things, but its a lot more grime and serious.'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I went to a court hearing for unemployment with my former employer, and I felt great about it since I was so prepared with all of the documents and everything I needed to show the court I was in the right for quitting.'},
#    {'role': 'assistant', 'content': 'Did it go your way?'},
#    {'role': 'user',
#     'content': 'Yes, I actually ended up winning it and they gave me 6 months of unemployment pay.'},
#    {'role': 'assistant',
#     'content': 'That is great - have you found another job yet?'},
#    {'role': 'user',
#     'content': ' Yes I am currently working as a processing assistant at a warehouse. I love it. Much better than my last job'}]},
#  {'messages': [{'role': 'user',
#     'content': 'Today traffic was horrible and was so frustrating!'},
#    {'role': 'assistant', 'content': 'I hate traffic too, it makes me angry'},
#    {'role': 'user',
#     'content': 'Yes! People were constantly cutting me off,not signalling and slamming on their brakes'},
#    {'role': 'assistant',
#     'content': 'People are so rude when they drive these days'}]},
#  {'messages': [{'role': 'user',
#     'content': "The grudge scared me when I was 10 to which I couldn't navigate my own house."},
#    {'role': 'assistant',
#     'content': 'I can imagine! That was a terrifying movie.'},
#    {'role': 'user',
#     'content': 'And yet I still felt as if I had to see the sequels when they came out too.'},
#    {'role': 'assistant',
#     'content': 'That happened to me too.. with the other Exorcist movies and the Ring movies. Even though they scared me, I was too curious to not see the others.'}]},
#  {'messages': [{'role': 'user',
#     'content': 'My best friend did amazing in school, despite having 2 children and not doing great academically in school. She ended up getting honors in her first 2 semesters.'},
#    {'role': 'assistant',
#     'content': 'She sounds like a person with great ability. Great choice of friend.'},
#    {'role': 'user',
#     'content': 'She has been my friend for 19 years. She pushes me to do better too.'},
#    {'role': 'assistant',
#     'content': "That's great. I wish I had someone so close like that!"},
#    {'role': 'user',
#     'content': 'I hope you find someone like that. I believe everyone needs and deserves friends like that.'}]},
#  {'messages': [{'role': 'user',
# ...
#    {'role': 'assistant',
#     'content': 'Oh wow! I would be very angry as well! Unless it was some kind of emergency or extenuating circumstance'},
#    {'role': 'user',
#     'content': "I am not sure. I just don't know why he didn't show"},
#    {'role': 'assistant',
#     'content': "He didn't even call to let you know whats going on?"}]},
#  {'messages': [{'role': 'user',
#     'content': 'I am confident that I will have a great day tomorrow'},
#    {'role': 'assistant',
#     'content': 'That is a great mindset to have, and should lead to a great day!'},
#    {'role': 'user',
#     'content': 'That is so true. Getting to know you also makes it seem like a great day already leading to tomorrow.'},
#    {'role': 'assistant',
#     'content': 'That is a very kind thing to say! i appreciate that'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I have trusting issues because my fiance left  me'},
#    {'role': 'assistant',
#     'content': "That is sad to hear. Don't worry, you will find someone that is for you."},
#    {'role': 'user',
#     'content': "I know but it's so hard because no one wants to be with me"},
#    {'role': 'assistant',
#     'content': 'It seems like that but it is not true. You have to be patient and you will find your love one day.'}]},
#  {'messages': [{'role': 'user',
#     'content': "Flying typically doesn't bother me too much, because I love travel. However I was a bit concerned on a flight once right after a travel advisory had been issued."},
#    {'role': 'assistant',
#     'content': 'I would have been terrified, like need a nice strong drink type of terrified! How did it end up going?'},
#    {'role': 'user',
#     'content': 'Well i did have a few of those. It went fine. I was still nervous even after we landed in a foreign country. I just watched my surroundings. Everything went great.'},
#    {'role': 'assistant',
#     'content': 'Im glad it all went well! It seems that sometimes when you are extremely nervous it can make time pass quickly too. '}]},
#  {'messages': [{'role': 'user',
#     'content': 'I am so lonely right now because no one wants to be with me'},
#    {'role': 'assistant',
#     'content': "I'm sad to hear that. Have you tried using social media to make new friends?"},
#    {'role': 'user', 'content': 'Yeah, but no luck'},
#    {'role': 'assistant',
#     'content': 'Try going to the park then. You could run into someone that is into you.'}]},
#  {'messages': [{'role': 'user',
#     'content': 'when i was younger I was really getting into graphic design and really wanted a new Apple computer. I knew my parents couldnt afford it, but they somehow made it happen and surprised me on Christmas..'},
#    {'role': 'assistant', 'content': 'That is awesome! Parents are the best'},
#    {'role': 'user',
#     'content': "yea my parents are pretty great. Pretty maddening at times, but I wouldn't trade them."},
#    {'role': 'assistant',
#     'content': 'lol i know the feeling! and being a parent i now understnd'},
#    {'role': 'user',
#     'content': 'I hope to be there one day and see it from that side.'}]},
#  {'messages': [{'role': 'user',
#     'content': 'i felt really good when i won a poker tournament last week'},
#    {'role': 'assistant', 'content': 'awesome! was it hold em?'},
#    {'role': 'user',
#     'content': 'yes it was, it took a long time to do but at the end it was worth it'},
#    {'role': 'assistant', 'content': 'most def, i love playing hold em'}]},
#  {'messages': [{'role': 'user',
#     'content': 'Spiders is one of my gratest fear they make me so scared'},
#    {'role': 'assistant',
#     'content': "I also do not like spiders. I don't even like watching Spiderman due to not liking spiders."},
#    {'role': 'user',
#     'content': 'i have tried to overcome my fear but i just cant they make my skin temble'},
#    {'role': 'assistant',
#     'content': 'Maybe you can go see a doctor and he can help you with your fear.'}]},
#  {'messages': [{'role': 'user',
#     'content': 'i am impressed that video games grow so much every year'},
#    {'role': 'assistant',
#     'content': 'The only video game I have ever played is Super Mario.'},
#    {'role': 'user',
#     'content': 'that is a great game the growth on video games has been amazing this past few years'},
#    {'role': 'assistant',
#     'content': 'It is a classic, even my kids enjoy playing it.'}]},
#  {'messages': [{'role': 'user',
#     'content': 'We went out to dinner for our first anniversary and they got our order all wrong.'},
#    {'role': 'assistant',
#     'content': 'thats always terrible, but congrats on the anniversary!'},
#    {'role': 'user',
#     'content': 'Thank you. The restaurant came highly rated by a lot of people so I guess my expectations were high. I tried not to let it bother me.'},
#    {'role': 'assistant',
#     'content': 'that makes the situation worse when your expectations are through the roof'}]},
#  {'messages': [{'role': 'user',
#     'content': 'My wife flew home to see family. It is very quite at home now.'},
#    {'role': 'assistant',
#     'content': "I definitely relate to that feeling, why can't they take us with them!?"},
#    {'role': 'user',
#     'content': 'I know, that would of been nice! Instead I was all alone for the last few weeks. '},
#    {'role': 'assistant',
#     'content': 'Well, I hope she gets home soon, to make the home, a home again! :)'},
#    {'role': 'user',
#     'content': "Me too, a home doesn't feel like a home without a woman. "}]},
#  {'messages': [{'role': 'user',
#     'content': 'i am really impressed everytime i see my nephew on how fast he is growing'},
#    {'role': 'assistant',
#     'content': 'It is pretty crazy how fast grow up when you get older, it seems like a couple of weeks and they are in high school'},
#    {'role': 'user',
#     'content': 'yeah but i dont see him very often maybe that is why i always get shocked when i see him'},
#    {'role': 'assistant',
#     'content': "That's definitely a factor, sometimes I forget about some of my nephews even exist."}]},
#  {'messages': [{'role': 'user',
#     'content': 'When I got the phone call that my mom had cancer I was so upset.'},
#    {'role': 'assistant',
#     'content': 'I am so sorry to hear that. No one should have to go through something like that.'},
#    {'role': 'user',
#     'content': "It's hard watching one of your parents get sick. We were at the movie theater when I found out and I had to leave."},
#    {'role': 'assistant',
#     'content': "I'm sure I would have done the same thing! But stay strong, many people have beaten cancer! Keep a positive attitude and stay by her side!"}]},
#  {'messages': [{'role': 'user',
#     'content': 'one of the best days of my life was when i graduated from high school'},
#    {'role': 'assistant',
#     'content': 'that was an awesome day for me too, hard to believe it was nearly  10 years ago'},
#    {'role': 'user',
#     'content': 'i know right time goes really fast and you dont even noticed, for me it was 13 years ago'},
#    {'role': 'assistant',
#     'content': 'agreed! its a shame growing up how fast you wanted to be an adult'}]},
#  {'messages': [{'role': 'user',
#     'content': 'The other night I was driving home in the rain and slid into the guard rail. It is going to cost so much to get my car fixed!'},
#    {'role': 'assistant',
#     'content': "Oh man, now that sucks! You gotta be careful on those wet roads. At least you're okay."},
#    {'role': 'user',
#     'content': "I know, I will have to be more careful next time. I shouldn't eat ice-cream while driving, "},
#    {'role': 'assistant', 'content': 'Is your car still drivable?'},
#    {'role': 'user',
#     'content': "It will still move, but I can't steer very well with the front tires missing. "}]},
#  {'messages': [{'role': 'user',
#     'content': 'There is a tornado coming. But I have the pantry full and am ready this time.'},
#    {'role': 'assistant',
#     'content': 'Good thinking.  You can never be too prepared, only under prepared.'},
#    {'role': 'user',
#     'content': 'You never know how long the power might be out for! '},
#    {'role': 'assistant',
#     'content': "Yep! or if you're house will be hit.  Many possibilities with tornadoes!"},
#    {'role': 'user',
#     'content': 'It could take a while for any sort of rescue to come! '}]},
#  {'messages': [{'role': 'user',
#     'content': 'I had a pretty large loan, with a bit of a high interest rate, and a high monthly payment. My mother decided to pay it off for me, out of the blue!'},
#    {'role': 'assistant', 'content': 'oh my goodness. what a blessing'},
#    {'role': 'user',
#     'content': "Yes, I couldn't believe it. She's so sweet and giving, but I sure didn't expect her to do that!"},
#    {'role': 'assistant',
#     'content': 'it much be a huge weight off of your shoulder'}]},
#  {'messages': [{'role': 'user',
#     'content': 'My husband is the most faithful man I know'},
#    {'role': 'assistant',
#     'content': 'that is great to hear! a faithful spouse is a blessing'},
#    {'role': 'user',
#     'content': 'I have so many health problems and he is always there for many no matter what being loving and caring'},
#    {'role': 'assistant',
#     'content': 'i am sorry to hear about that! i hope everything gets better for you!'}]},
#  {'messages': [{'role': 'user',
#     'content': "I left the front door unlocked and the mailman robbed me. I couldn't believe I would do that."},
#    {'role': 'assistant',
#     'content': 'oh no, I hope you did any sustain any injury'},
#    {'role': 'user',
#     'content': "Only my pride! I wasn't at home when he robbed me. He took a lot of valuables. "},
#    {'role': 'assistant', 'content': 'Yea, he will definitely get caught'},
#    {'role': 'user',
#     'content': 'I hope so! A federal worker like that should have more integrity! '}]},
#  {'messages': [{'role': 'user',
#     'content': 'I have always been afraid of snakes i dont know what to do to control my fear for them'},
#    {'role': 'assistant',
#     'content': 'that makes two of us! i am terrified of all snakes'},
#    {'role': 'user',
#     'content': 'yes, i one time i was taking a hike and 3 meters to my left was a rattle snake i jumped like a rabbit and ran back to my friends'},
#    {'role': 'assistant',
#     'content': 'eww thats disgusting, and makes it worse it was a poisonous snake'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I was annoyed when my wife left me'},
#    {'role': 'assistant',
#     'content': "Ah that's terrible. I would be annoyed as well I think."},
#    {'role': 'user', 'content': 'Yeah its been a rough 2 weeks for me'},
#    {'role': 'assistant',
#     'content': "I'm sorry to here that, but life goes on and tomorrow is another day. We just have to make the best with what we are given. You'll get through this."}]},
#  {'messages': [{'role': 'user',
#     'content': 'I was afraid when I went into the movies alone'},
#    {'role': 'assistant', 'content': 'really why is that?'},
#    {'role': 'user',
#     'content': 'Because I have always been with someone, so going in alone just frightened me'},
#    {'role': 'assistant',
#     'content': 'I think with time you will get used to it.'}]},
#  {'messages': [{'role': 'user',
#     'content': "I've been married almost 23 years. My husband travel so much, but we both have trust in each other to be true and loyal."},
#    {'role': 'assistant',
#     'content': 'That is great, Why does he travel so much?'},
#    {'role': 'user',
#     'content': 'for his job. So, it can be hard, but we trust each other.'},
#    {'role': 'assistant', 'content': 'What does he do for his job?'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I am hopeful that my friend will be able to make it to my party'},
#    {'role': 'assistant',
#     'content': 'Thats good, is it very important that this friend be there?'},
#    {'role': 'user', 'content': 'It is to me because he is my best friend'},
#    {'role': 'assistant',
#     'content': 'That makes sense! Im sure he will be there for you!'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I have been exercising and taking care of myself more lately.'},
#    {'role': 'assistant',
#     'content': 'There you go! I need to work on that area of my life as well.'},
#    {'role': 'user', 'content': 'I think many do, but man does it feel good.'},
#    {'role': 'assistant',
#     'content': 'I bet you have more energy and more confidence for sure!'}]},
#  {'messages': [{'role': 'user',
#     'content': 'I am joyful that I am with my wife'},
#    {'role': 'assistant', 'content': 'How you been together long?'},
#    {'role': 'user', 'content': 'We have been together for 10 years'},
#    {'role': 'assistant',
#     'content': "Awesome. I've got you beat by 1 year. You know I just read the average couple from the time to meet to the time the ends things is 6 years. If you make it past that it will probably last for every. "}]},
#  {'messages': [{'role': 'user',
#     'content': 'I felt pretty luck the other day! I won $100 on a scratch off ticket! I never win!'},
#    {'role': 'assistant', 'content': 'You are pretty lucky!'},
#    {'role': 'user',
#     'content': 'Not usually, I never win. so, it was very unexpected.'},
#    {'role': 'assistant',
#     'content': 'Maybe I should buy some. I never win either. Its about time'}]},
#  {'messages': [{'role': 'user',
#     'content': 'My sister was given $1,000 by my grandma as a graduation present. She did not give me a penny.'},
#    {'role': 'assistant', 'content': 'I am sorry, maybe she will share?'},
#    {'role': 'user',
#     'content': "Perhaps, I just don't understand why I was left out. Seems unfair."},
#    {'role': 'assistant', 'content': 'That is infair'}]},
#  {'messages': [{'role': 'user',
#     'content': 'We went on our vacation about a week ago to the beach and it rained several days while we were there. We wanted to go to the beach every day!'},
#    {'role': 'assistant',
#     'content': 'I hate when that happens! Especially when you have been waiting for the beach!'},
#    {'role': 'user',
#     'content': 'Yes, and when you pay a fortune to get beachfront! But, we still had a good time, just wished we could have had less rain!'},
#    {'role': 'assistant',
#     'content': "That's what matters most, that you had a good time and made memories!"}]},
#  {'messages': [{'role': 'user',
#     'content': 'I was given the opportunity to work at a new job that I was hoping to get! I never thought it would be possible!'},
#    {'role': 'assistant',
#     'content': "Congratulations! I'm sure you earned it!"},
#    {'role': 'user',
#     'content': 'Thank you! I feel very fortunate to have been given the opportunity.'},
#    {'role': 'assistant',
#     'content': "You're welcome. I wish you the best in the new position."}]},
#  {'messages': [{'role': 'user',
#     'content': 'I fell down in a mud puddle today while walking to lunch. I was covered in mud for the rest of the work day.'},
#    {'role': 'assistant',
#     'content': 'Oh no! That is awful, that can mess with your mood.'},
#    {'role': 'user',
#     'content': 'No kidding! It was hard to keep a good attitude for the rest of the day.'},
#    {'role': 'assistant', 'content': 'I can understand that!'}]},
#  {'messages': [{'role': 'user',
#     'content': 'My husband works nights a lot right now.'},
#    {'role': 'assistant', 'content': 'I bet that is a rough schedule.'},
#    {'role': 'user', 'content': 'It really is, i hate being alone at night.'},
#    {'role': 'assistant', 'content': 'Does he get any nights off?'},
#    {'role': 'user',
#     'content': 'A few, but he still has to sleep all day, makes doing things hard.'}]},
#  {'messages': [{'role': 'user',
#     'content': "I'm anxious (if excited!) about an upcoming move -- we've lived overseas before, but this is such a different state and climate, I'm not sure what to expect!"},
#    {'role': 'assistant',
#     'content': 'It sounds like a great chance to start over fresh! Where are you moving to?'},
#    {'role': 'user',
#     'content': "Alaska! We've got some transition time, but I've been doing deep research on Anchorage -- and the more I see, the more I like!"},
#    {'role': 'assistant',
#     'content': "Oh wow! How exciting! I can't wait to come visit you there so you can show me the sights!"}]},
#  ...]

# %%
output_file = '/content/train.jsonl'

# Write the list of conversations to a JSONL file
with open(output_file, 'w') as jsonl_file:
    for conversation in train_df_json:
        jsonl_file.write(json.dumps(conversation) + '\n')

# %%
output_file = '/content/valid.jsonl'

# Write the list of conversations to a JSONL file
with open(output_file, 'w') as jsonl_file:
    for conversation in valid_df_json:
        jsonl_file.write(json.dumps(conversation) + '\n')

# %%
output_file = '/content/test.jsonl'

# Write the list of conversations to a JSONL file
with open(output_file, 'w') as jsonl_file:
    for conversation in test_df_json:
        jsonl_file.write(json.dumps(conversation) + '\n')

# %% [markdown]
# ## Reformat dataset
# If you upload this ultrachat_chunk_train.jsonl to Mistral API, you might encounter an error message “Invalid file format” due to data formatting issues. To reformat the data into the correct format, you can download the reformat_dataset.py script and use it to validate and reformat both the training and evaluation data:

# %%
# download the validation and reformat script
# !wget https://raw.githubusercontent.com/mistralai/mistral-finetune/main/utils/reformat_data.py
# Out:
# --2024-10-06 10:00:23--  https://raw.githubusercontent.com/mistralai/mistral-finetune/main/utils/reformat_data.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3381 (3.3K) [text/plain]
# Saving to: ‘reformat_data.py’
#
# reformat_data.py    100%[===================>]   3.30K  --.-KB/s    in 0s
#
# 2024-10-06 10:00:24 (53.9 MB/s) - ‘reformat_data.py’ saved [3381/3381]

# %%
# validate and reformat the training data
# !python reformat_data.py train.jsonl
# Out:
# Skipped 9th sample
# Skipped 325th sample
# Skipped 435th sample
# Skipped 529th sample
# Skipped 768th sample
# Skipped 1052th sample
# Skipped 1061th sample
# Skipped 1083th sample
# Skipped 1090th sample
# Skipped 1091th sample
# Skipped 1953th sample
# Skipped 1954th sample
# Skipped 2218th sample
# Skipped 2774th sample
# Skipped 3361th sample
# Skipped 4214th sample
# Skipped 4840th sample
# Skipped 5255th sample
# Skipped 5392th sample
# Skipped 6922th sample
# Skipped 7009th sample
# Skipped 7920th sample
# Skipped 8233th sample
# Skipped 8520th sample
# Skipped 8521th sample
# Skipped 8749th sample
# Skipped 8750th sample
# Skipped 10053th sample
# Skipped 11197th sample
# Skipped 12209th sample
# Skipped 12361th sample
# Skipped 13044th sample
# Skipped 13655th sample
# Skipped 13855th sample
# Skipped 14402th sample
# Skipped 15219th sample
# Skipped 15220th sample
# Skipped 15723th sample
# Skipped 15831th sample
# Skipped 15832th sample
# Skipped 16477th sample
# Skipped 16539th sample
# Skipped 16925th sample
# Skipped 17200th sample
# Skipped 17258th sample
# Skipped 17259th sample

# %%
# validate the reformat the eval data
# !python reformat_data.py valid.jsonl
# Out:
# Skipped 1247th sample

# %%
df_train.iloc[3674]['messages']
# Out:
# array([{'content': 'What are the dimensions of the cavity, product, and shipping box of the Sharp SMC1662DS microwave?: With innovative features like preset controls, Sensor Cooking and the Carousel® turntable system, the Sharp® SMC1662DS 1.6 cu. Ft. Stainless Steel Carousel Countertop Microwave makes reheating your favorite foods, snacks and beverages easier than ever. Use popcorn and beverage settings for one-touch cooking. Express Cook allows one-touch cooking up to six minutes. The convenient and flexible "+30 Sec" key works as both instant start option and allows you to add more time during cooking.\nThe Sharp SMC1662DS microwave is a bold design statement in any kitchen. The elegant, grey interior and bright white, LED interior lighting complements the stainless steel finish of this premium appliance.\nCavity Dimensions (w x h x d): 15.5" x 10.2" x 17.1"\nProduct Dimensions (w x h x d): 21.8" x 12.8" x 17.7"\nShipping Dimensions (w x h x d) : 24.4" x 15.0" x 20.5"', 'role': 'user'},
#        {'content': '', 'role': 'assistant'},
#        {'content': 'Can you help me find out the weight of the Sharp SMC1662DS microwave?', 'role': 'user'},
#        {'content': 'Yes, the weight of the Sharp SMC1662DS microwave is 36.4 pounds.', 'role': 'assistant'},
#        {'content': 'Can you tell me if the Sharp SMC1662DS microwave comes with a warranty?', 'role': 'user'},
#        {'content': 'Yes, the Sharp SMC1662DS microwave comes with a warranty. It has a 1-year limited warranty on parts and labor, a 4-year limited warranty on the magnetron tube, and an 8-year limited warranty on the magnetron tube for certain models. You should check the warranty details provided in the manual for complete information.', 'role': 'assistant'},
#        {'content': 'Can you remind me of the innovative features of the Sharp SMC1662DS microwave?', 'role': 'user'}],
#       dtype=object)

# %% [markdown]
# ## Upload dataset

# %%
from mistralai import Mistral
import os

api_key = userdata.get('MISTRAL_API_KEY') #os.environ["MISTRAL_API_KEY"]

client = Mistral(api_key=api_key)

train = client.files.upload(file={
    "file_name": "train.jsonl",
    "content": open("train.jsonl", "rb"),
})
valid = client.files.upload(file={
    "file_name": "valid.jsonl",
    "content": open("valid.jsonl", "rb"),
})

# %%
import json
def pprint(obj):
    print(json.dumps(obj.dict(), indent=4))

# %%
pprint(train)
# Out:
# {
#     "id": "7666ee20-04d6-4426-a98d-d9f057a40d17",
#     "object": "file",
#     "bytes": 8645590,
#     "created_at": 1728209570,
#     "filename": "train.jsonl",
#     "sample_type": "instruct",
#     "source": "upload",
#     "purpose": null,
#     "num_lines": 18361
# }

# %%
pprint(valid)
# Out:
# {
#     "id": "e224b685-143f-4b1a-ab1d-d1e3e2041680",
#     "object": "file",
#     "bytes": 1369301,
#     "created_at": 1728209571,
#     "filename": "valid.jsonl",
#     "sample_type": "instruct",
#     "source": "upload",
#     "purpose": null,
#     "num_lines": 2761
# }

# %% [markdown]
# ## Create a fine-tuning job

# %%
created_jobs = client.fine_tuning.jobs.create(
    model="mistral-large-latest",#"pixtral-12b-2409",
    training_files=[{"file_id": train.id, "weight": 1}],
    validation_files=[valid.id],
    hyperparameters={
    "training_steps": 10,
    "learning_rate":0.001
    },
    auto_start=True
)
created_jobs
# Out:
# JobOut(id='2f360255-6813-49e9-aa88-db52f6c8df96', auto_start=True, hyperparameters=TrainingParameters(training_steps=10, learning_rate=0.001, weight_decay=0.1, warmup_fraction=0.05, epochs=None, fim_ratio=None), model='mistral-large-latest', status='QUEUED', job_type='FT', created_at=1728209855, modified_at=1728209855, training_files=['7666ee20-04d6-4426-a98d-d9f057a40d17'], validation_files=['e224b685-143f-4b1a-ab1d-d1e3e2041680'], OBJECT='job', fine_tuned_model=None, suffix=None, integrations=[], trained_tokens=None, repositories=[], metadata=JobMetadataOut(expected_duration_seconds=None, cost=0.0, cost_currency=None, train_tokens_per_step=None, train_tokens=None, data_tokens=None, estimated_start_time=None))

# %%
pprint(created_jobs)
# Out:
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": null,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "QUEUED",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209855,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": null,
#         "cost": 0.0,
#         "cost_currency": null,
#         "train_tokens_per_step": null,
#         "train_tokens": null,
#         "data_tokens": null,
#         "estimated_start_time": null
#     }
# }

# %%
jobs = client.fine_tuning.jobs.list()
print(jobs)
# Out:
# total=22 data=[JobOut(id='2f360255-6813-49e9-aa88-db52f6c8df96', auto_start=True, hyperparameters=TrainingParameters(training_steps=10, learning_rate=0.001, weight_decay=0.1, warmup_fraction=0.05, epochs=1.2128452107595227, fim_ratio=None), model='mistral-large-latest', status='RUNNING', job_type='FT', created_at=1728209855, modified_at=1728209859, training_files=['7666ee20-04d6-4426-a98d-d9f057a40d17'], validation_files=['e224b685-143f-4b1a-ab1d-d1e3e2041680'], OBJECT='job', fine_tuned_model=None, suffix=None, integrations=[], trained_tokens=None, repositories=[], metadata=JobMetadataOut(expected_duration_seconds=900, cost=23.6, cost_currency='USD', train_tokens_per_step=262144, train_tokens=2621440, data_tokens=2161397, estimated_start_time=None)), JobOut(id='1efa1a26-50fe-49ac-89e2-f74c13f757aa', auto_start=False, hyperparameters=TrainingParameters(training_steps=10, learning_rate=0.0001, weight_decay=0.1, warmup_fraction=0.05, epochs=18.259603663845645, fim_ratio=None), model='mistral-large-latest', status='SUCCESS', job_type='FT', created_at=1728183994, modified_at=1728184840, training_files=['589e2fa5-91c2-4208-bbe8-eb1654544120'], validation_files=['8d3e5053-e388-4291-990b-589897eb680c'], OBJECT='job', fine_tuned_model='ft:mistral-large-latest:5aa386c9:20241006:1efa1a26', suffix=None, integrations=[WandbIntegrationOut(project='Cocoonie', TYPE='wandb', name=None, run_name=None)], trained_tokens=2621440, repositories=[], metadata=JobMetadataOut(expected_duration_seconds=900, cost=23.6, cost_currency='USD', train_tokens_per_step=262144, train_tokens=2621440, data_tokens=143565, estimated_start_time=None)), JobOut(id='12e3d2bd-6f1b-485c-a40c-06787095d811', auto_start=False, hyperparameters=TrainingParameters(training_steps=10, learning_rate=0.0001, weight_decay=0.1, warmup_fraction=0.05, epochs=9.129801831922823, fim_ratio=None), model='mistral-small-latest', status='SUCCESS', job_type='FT', created_at=1728183663, modified_at=1728183914, training_files=['7ad4829f-45d5-4158-a964-d883b721fbf5'], validation_files=['250ec680-62f2-447e-b70c-57241b7382fb'], OBJECT='job', fine_tuned_model='ft:mistral-small-latest:5aa386c9:20241006:12e3d2bd', suffix=None, integrations=[WandbIntegrationOut(project='Cocoonie', TYPE='wandb', name=None, run_name=None)], trained_tokens=1310720, repositories=[], metadata=JobMetadataOut(expected_duration_seconds=300, cost=5.25, cost_currency='USD', train_tokens_per_step=131072, train_tokens=1310720, data_tokens=143565, estimated_start_time=None)), JobOut(id='34d17884-65cb-4f82-96bf-2f405aa5a680', auto_start=False, hyperparameters=TrainingParameters(training_steps=10, learning_rate=0.0001, weight_decay=0.1, warmup_fraction=0.05, epochs=18.259603663845645, fim_ratio=None), model='open-mistral-nemo', status='SUCCESS', job_type='FT', created_at=1728181754, modified_at=1728181938, training_files=['4333a08c-d116-4fc8-b22b-d65f6e4e3e7e'], validation_files=['b6c4272b-4c4d-41e9-ba49-93bcf1744044'], OBJECT='job', fine_tuned_model='ft:open-mistral-nemo:5aa386c9:20241006:34d17884', suffix=None, integrations=[WandbIntegrationOut(project='Cocoonie', TYPE='wandb', name=None, run_name=None)], trained_tokens=2621440, repositories=[], metadata=JobMetadataOut(expected_duration_seconds=280, cost=2.63, cost_currency='USD', train_tokens_per_step=262144, train_tokens=2621440, data_tokens=143565, estimated_start_time=None)), JobOut(id='254ae550-9533-46f7-98ad-cb677826dcb2', auto_start=False, hyperparameters=TrainingParameters(training_steps=10, learning_rate=0.0001, weight_decay=0.1, warmup_fraction=0.05, epochs=9.129801831922823, fim_ratio=None), model='open-mistral-7b', status='SUCCESS', job_type='FT', created_at=1728180480, modified_at=1728180628, training_files=['ff5f8b09-33e4-412a-9ea8-64d66c2dac76'], validation_files=['3c5c6bea-d382-4d85-b71a-1d601fa52d63'], OBJECT='job', fine_tuned_model='ft:open-mistral-7b:5aa386c9:20241006:254ae550', suffix=None, integrations=[WandbIntegrationOut(project='Cocoonie', TYPE='wandb', name=N ...

# %%
retrieved_jobs = client.fine_tuning.jobs.get(job_id = created_jobs.id)
retrieved_jobs
# Out:
# DetailedJobOut(id='2f360255-6813-49e9-aa88-db52f6c8df96', auto_start=True, hyperparameters=TrainingParameters(training_steps=10, learning_rate=0.001, weight_decay=0.1, warmup_fraction=0.05, epochs=1.2128452107595227, fim_ratio=None), model='mistral-large-latest', status='RUNNING', job_type='FT', created_at=1728209855, modified_at=1728209859, training_files=['7666ee20-04d6-4426-a98d-d9f057a40d17'], validation_files=['e224b685-143f-4b1a-ab1d-d1e3e2041680'], OBJECT='job', fine_tuned_model=None, suffix=None, integrations=[], trained_tokens=None, repositories=[], metadata=JobMetadataOut(expected_duration_seconds=900, cost=23.6, cost_currency='USD', train_tokens_per_step=262144, train_tokens=2621440, data_tokens=2161397, estimated_start_time=None), events=[EventOut(name='status-updated', created_at=1728209858, data={'status': 'RUNNING'}), EventOut(name='status-updated', created_at=1728209856, data={'status': 'QUEUED'}), EventOut(name='status-updated', created_at=1728209856, data={'status': 'VALIDATED'}), EventOut(name='status-updated', created_at=1728209856, data={'status': 'RUNNING'}), EventOut(name='status-updated', created_at=1728209855, data={'status': 'QUEUED'})], checkpoints=[])

# %%
import time

retrieved_job = client.fine_tuning.jobs.get(job_id = created_jobs.id)
while retrieved_job.status in ["RUNNING", "QUEUED"]:
    retrieved_job = client.fine_tuning.jobs.get(job_id = created_jobs.id)
    pprint(retrieved_job)
    print(f"Job is {retrieved_job.status}, waiting 10 seconds")
    time.sleep(10)
# Out:
# Streaming output truncated to the last 5000 lines.
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
# ...
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": []
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 8.67736,
#                 "valid_loss": 8.569411,
#                 "valid_mean_token_accuracy": 379.882721
#             },
#             "step_number": 10,
#             "created_at": 1728210648
#         }
#     ]
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 8.67736,
#                 "valid_loss": 8.569411,
#                 "valid_mean_token_accuracy": 379.882721
#             },
#             "step_number": 10,
#             "created_at": 1728210648
#         }
#     ]
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "RUNNING",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728209859,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": null,
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": null,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 8.67736,
#                 "valid_loss": 8.569411,
#                 "valid_mean_token_accuracy": 379.882721
#             },
#             "step_number": 10,
#             "created_at": 1728210648
#         }
#     ]
# }
# Job is RUNNING, waiting 10 seconds
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "SUCCESS",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728210677,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": "ft:mistral-large-latest:5aa386c9:20241006:2f360255",
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": 2621440,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728210677,
#             "data": {
#                 "status": "SUCCESS"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 8.67736,
#                 "valid_loss": 8.569411,
#                 "valid_mean_token_accuracy": 379.882721
#             },
#             "step_number": 10,
#             "created_at": 1728210648
#         }
#     ]
# }
# Job is SUCCESS, waiting 10 seconds

# %%
# List jobs
jobs = client.fine_tuning.jobs.list()
pprint(jobs)
# Out:
# {
#     "total": 22,
#     "data": [
#         {
#             "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 1.2128452107595227,
#                 "fim_ratio": null
#             },
#             "model": "mistral-large-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1728209855,
#             "modified_at": 1728210677,
#             "training_files": [
#                 "7666ee20-04d6-4426-a98d-d9f057a40d17"
#             ],
#             "validation_files": [
#                 "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#             ],
#             "fine_tuned_model": "ft:mistral-large-latest:5aa386c9:20241006:2f360255",
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": 2621440,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 900,
#                 "cost": 23.6,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 262144,
#                 "train_tokens": 2621440,
#                 "data_tokens": 2161397,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "1efa1a26-50fe-49ac-89e2-f74c13f757aa",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 18.259603663845645,
#                 "fim_ratio": null
#             },
#             "model": "mistral-large-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1728183994,
#             "modified_at": 1728184840,
#             "training_files": [
#                 "589e2fa5-91c2-4208-bbe8-eb1654544120"
#             ],
#             "validation_files": [
#                 "8d3e5053-e388-4291-990b-589897eb680c"
#             ],
#             "fine_tuned_model": "ft:mistral-large-latest:5aa386c9:20241006:1efa1a26",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "Cocoonie",
#                     "name": null,
#                     "run_name": null
#                 }
#             ],
#             "trained_tokens": 2621440,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 900,
#                 "cost": 23.6,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 262144,
#                 "train_tokens": 2621440,
#                 "data_tokens": 143565,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "12e3d2bd-6f1b-485c-a40c-06787095d811",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 9.129801831922823,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1728183663,
#             "modified_at": 1728183914,
#             "training_files": [
#                 "7ad4829f-45d5-4158-a964-d883b721fbf5"
#             ],
#             "validation_files": [
#                 "250ec680-62f2-447e-b70c-57241b7382fb"
#             ],
#             "fine_tuned_model": "ft:mistral-small-latest:5aa386c9:20241006:12e3d2bd",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "Cocoonie",
#                     "name": null,
#                     "run_name": null
#                 }
#             ],
#             "trained_tokens": 1310720,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 300,
#                 "cost": 5.25,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 143565,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "34d17884-65cb-4f82-96bf-2f405aa5a680",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 18.259603663845645,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-nemo",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1728181754,
#             "modified_at": 1728181938,
#             "training_files": [
#                 "4333a08c-d116-4fc8-b22b-d65f6e4e3e7e"
#             ],
#             "validation_files": [
#                 "b6c4272b-4c4d-41e9-ba49-93bcf1744044"
#             ],
#             "fine_tuned_model": "ft:open-mistral-nemo:5aa386c9:20241006:34d17884",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "Cocoonie",
#                     "name": null,
#                     "run_name": null
#                 }
#             ],
#             "trained_tokens": 2621440,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 280,
#                 "cost": 2.63,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 262144,
#                 "train_tokens": 2621440,
#                 "data_tokens": 143565,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "254ae550-9533-46f7-98ad-cb677826dcb2",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 9.129801831922823,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1728180480,
#             "modified_at": 1728180628,
#             "training_files": [
#                 "ff5f8b09-33e4-412a-9ea8-64d66c2dac76"
#             ],
#             "validation_files": [
#                 "3c5c6bea-d382-4d85-b71a-1d601fa52d63"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:5aa386c9:20241006:254ae550",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "Cocoonie",
#                     "name": null,
#                     "run_name": null
#                 }
#             ],
#             "trained_tokens": 1310720,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 170,
#                 "cost": 2.63,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 143565,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "58bcf0cf-fbdb-457a-925c-5cb2b8b28ef1",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 80.89366166759243,
#                 "fim_ratio": null
#             },
#             "model": "mistral-large-latest",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1728180426,
#             "modified_at": 1728181268,
#             "training_files": [
#                 "0f4c4ef1-007d-480f-8c4a-fe6cd364540b"
#             ],
#             "validation_files": [],
#             "fine_tuned_model": "ft:mistral-large-latest:5aa386c9:20241006:58bcf0cf",
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": 2621440,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 890,
#                 "cost": 23.6,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 262144,
#                 "train_tokens": 2621440,
#                 "data_tokens": 32406,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "a71d54de-2244-4594-acdc-934aee283d53",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 80.89366166759243,
#                 "fim_ratio": null
#             },
#             "model": "mistral-large-latest",
#             "status": "FAILED_VALIDATION",
#             "job_type": "FT",
#             "created_at": 1728180220,
#             "modified_at": 1728180237,
#             "training_files": [
#                 "0f4c4ef1-007d-480f-8c4a-fe6cd364540b"
#             ],
#             "validation_files": [
#                 "0f4c4ef1-007d-480f-8c4a-fe6cd364540b"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 890,
#                 "cost": 23.6,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 262144,
#                 "train_tokens": 2621440,
#                 "data_tokens": 32406,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "58cbad29-beaf-44d0-87f9-1c8c4fa65667",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 9.129801831922823,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1728179666,
#             "modified_at": 1728179811,
#             "training_files": [
#                 "f4dfaee1-d5e8-412f-a313-42932c7f773c"
#             ],
#             "validation_files": [
#                 "f84a902c-d1db-426c-9b50-86212dd350cc"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:5aa386c9:20241006:58cbad29",
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "Cocoonie",
#                     "name": null,
#                     "run_name": null
#                 }
#             ],
#             "trained_tokens": 1310720,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 210,
#                 "cost": 2.63,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 143565,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "1910d0ce-830a-4d54-8032-71020c0d8875",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 9.129801831922823,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "VALIDATED",
#             "job_type": "FT",
#             "created_at": 1728179558,
#             "modified_at": 1728179559,
#             "training_files": [
#                 "dd9762c9-06ea-4d5c-a638-a3a939ba39fe"
#             ],
#             "validation_files": [
#                 "2d9a256c-863a-4354-a033-ab93d26148ff"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [
#                 {
#                     "project": "Cocoonie",
#                     "name": null,
#                     "run_name": null
#                 }
#             ],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 210,
#                 "cost": 2.63,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 143565,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "46aa7075-1090-4921-a9d6-ee60296db261",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 80.89366166759243,
#                 "fim_ratio": null
#             },
#             "model": "mistral-large-latest",
#             "status": "FAILED_VALIDATION",
#             "job_type": "FT",
#             "created_at": 1728179392,
#             "modified_at": 1728179408,
#             "training_files": [
#                 "c7130e9a-9289-4fcd-9ce7-a4e0a39a6468"
#             ],
#             "validation_files": [
#                 "c7130e9a-9289-4fcd-9ce7-a4e0a39a6468"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 890,
#                 "cost": 23.6,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 262144,
#                 "train_tokens": 2621440,
#                 "data_tokens": 32406,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "d1979af7-e185-4436-a7e6-9a3bbf587221",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 80.89366166759243,
#                 "fim_ratio": null
#             },
#             "model": "mistral-large-latest",
#             "status": "FAILED_VALIDATION",
#             "job_type": "FT",
#             "created_at": 1728179375,
#             "modified_at": 1728179377,
#             "training_files": [
#                 "c7130e9a-9289-4fcd-9ce7-a4e0a39a6468"
#             ],
#             "validation_files": [
#                 "c7130e9a-9289-4fcd-9ce7-a4e0a39a6468"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 890,
#                 "cost": 23.6,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 262144,
#                 "train_tokens": 2621440,
#                 "data_tokens": 32406,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "20471d27-28c8-4853-a42f-03bbe9c226ce",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 9.129801831922823,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "VALIDATED",
#             "job_type": "FT",
#             "created_at": 1728179007,
#             "modified_at": 1728179007,
#             "training_files": [
#                 "0b428c67-db80-4a91-a030-67e8e3892b0a"
#             ],
#             "validation_files": [
#                 "66a6d9c7-f701-46aa-8109-0a831008e3fa"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 210,
#                 "cost": 2.63,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 143565,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "23d1f843-1266-4627-9483-d09d3ef250bd",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 9.129801831922823,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "VALIDATED",
#             "job_type": "FT",
#             "created_at": 1728178608,
#             "modified_at": 1728178611,
#             "training_files": [
#                 "bf7b98e5-97ab-42f8-8f11-cdb8b91e03ee"
#             ],
#             "validation_files": [
#                 "41b97298-3c63-479e-b76a-1ecd1b0b96a7"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 210,
#                 "cost": 2.63,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 143565,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "9dc85934-8cf5-44d0-9d02-6d1b6b4a9dfc",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 9.129801831922823,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "SUCCESS",
#             "job_type": "FT",
#             "created_at": 1728178167,
#             "modified_at": 1728178276,
#             "training_files": [
#                 "b673861a-1e1a-4aad-96eb-655a8e1bd308"
#             ],
#             "validation_files": [
#                 "ad1b61ed-2ea2-41ae-8d67-e4cedd6463a7"
#             ],
#             "fine_tuned_model": "ft:open-mistral-7b:5aa386c9:20241006:9dc85934",
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": 1310720,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 210,
#                 "cost": 2.63,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 143565,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "1af2741c-932d-4577-9e4a-8a24e76f686c",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 9.129801831922823,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "VALIDATED",
#             "job_type": "FT",
#             "created_at": 1728178052,
#             "modified_at": 1728178054,
#             "training_files": [
#                 "8e9618ff-a515-4ed9-a6d6-f99ddadb172f"
#             ],
#             "validation_files": [
#                 "010fb9c0-9001-4929-90c6-f23d6c8efc79"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 210,
#                 "cost": 2.63,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 143565,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "950eedf5-a5d7-40aa-b72d-0349dd273777",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 30,
#                 "learning_rate": 1e-05,
#                 "weight_decay": 1e-05,
#                 "warmup_fraction": 0.05,
#                 "epochs": 138.86216760250028,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "FAILED_VALIDATION",
#             "job_type": "FT",
#             "created_at": 1728174434,
#             "modified_at": 1728174490,
#             "training_files": [
#                 "79aa6958-2ee2-431a-9930-7e27e5c2b50e"
#             ],
#             "validation_files": [],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 840,
#                 "cost": 15.73,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 3932160,
#                 "data_tokens": 28317,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "827cc467-2b50-4fbc-ac71-d8e9087ac7b2",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 30,
#                 "learning_rate": 1e-05,
#                 "weight_decay": 1e-05,
#                 "warmup_fraction": 0.05,
#                 "epochs": 138.86216760250028,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "FAILED_VALIDATION",
#             "job_type": "FT",
#             "created_at": 1728174052,
#             "modified_at": 1728174076,
#             "training_files": [
#                 "58726473-36ef-4a7b-975f-136f25c647a8"
#             ],
#             "validation_files": [],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 840,
#                 "cost": 15.73,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 3932160,
#                 "data_tokens": 28317,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "c21c0ca6-0f58-4e54-b9e0-d4ebb499edd4",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 30,
#                 "learning_rate": 1e-05,
#                 "weight_decay": 1e-05,
#                 "warmup_fraction": 0.05,
#                 "epochs": 138.86216760250028,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "FAILED_VALIDATION",
#             "job_type": "FT",
#             "created_at": 1728173820,
#             "modified_at": 1728173950,
#             "training_files": [
#                 "58726473-36ef-4a7b-975f-136f25c647a8"
#             ],
#             "validation_files": [],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 840,
#                 "cost": 15.73,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 3932160,
#                 "data_tokens": 28317,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "f6133098-777f-4609-8cef-141006bc04ac",
#             "auto_start": false,
#             "hyperparameters": {
#                 "training_steps": 30,
#                 "learning_rate": 1e-05,
#                 "weight_decay": 1e-05,
#                 "warmup_fraction": 0.05,
#                 "epochs": 138.86216760250028,
#                 "fim_ratio": null
#             },
#             "model": "mistral-small-latest",
#             "status": "FAILED_VALIDATION",
#             "job_type": "FT",
#             "created_at": 1728173732,
#             "modified_at": 1728173735,
#             "training_files": [
#                 "e5105ca8-5361-4e58-9618-fd77947f9895"
#             ],
#             "validation_files": [],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 840,
#                 "cost": 15.73,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 3932160,
#                 "data_tokens": 28317,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "967467ae-40f6-476f-b9e5-89e67a4ff78a",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 13797.052631578947,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "FAILED_VALIDATION",
#             "job_type": "FT",
#             "created_at": 1728129413,
#             "modified_at": 1728129415,
#             "training_files": [
#                 "3674103b-e61e-4e20-bdc8-654fd05489a9"
#             ],
#             "validation_files": [
#                 "dd55b6e4-f22c-47f3-b16e-85453d69fca4"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 220,
#                 "cost": 2.63,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 95,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "cf61e55c-d356-4d63-8737-d10da9af104d",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 2664.0650406504064,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "FAILED_VALIDATION",
#             "job_type": "FT",
#             "created_at": 1728129165,
#             "modified_at": 1728129168,
#             "training_files": [
#                 "6834fde1-f9d5-42cf-b3b7-104f0189425f"
#             ],
#             "validation_files": [
#                 "c111a518-ddb2-47ae-8cda-4c280068ecc1"
#             ],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 220,
#                 "cost": 2.63,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 492,
#                 "estimated_start_time": null
#             }
#         },
#         {
#             "id": "3ee0a6a5-f895-402e-b515-2d0ec695c1f2",
#             "auto_start": true,
#             "hyperparameters": {
#                 "training_steps": 10,
#                 "learning_rate": 0.0001,
#                 "weight_decay": 0.1,
#                 "warmup_fraction": 0.05,
#                 "epochs": 13374.69387755102,
#                 "fim_ratio": null
#             },
#             "model": "open-mistral-7b",
#             "status": "FAILED_VALIDATION",
#             "job_type": "FT",
#             "created_at": 1728128921,
#             "modified_at": 1728128946,
#             "training_files": [
#                 "b1e99986-ab23-4f32-8610-27980eaa35f5"
#             ],
#             "validation_files": [],
#             "fine_tuned_model": null,
#             "suffix": null,
#             "integrations": [],
#             "trained_tokens": null,
#             "repositories": [],
#             "metadata": {
#                 "expected_duration_seconds": 220,
#                 "cost": 2.63,
#                 "cost_currency": "USD",
#                 "train_tokens_per_step": 131072,
#                 "train_tokens": 1310720,
#                 "data_tokens": 98,
#                 "estimated_start_time": null
#             }
#         }
#     ],
#     "OBJECT": "list"
# }

# %%
# Retrieve a jobs
retrieved_jobs = client.fine_tuning.jobs.get(job_id = created_jobs.id)
pprint(retrieved_jobs)
# Out:
# {
#     "id": "2f360255-6813-49e9-aa88-db52f6c8df96",
#     "auto_start": true,
#     "hyperparameters": {
#         "training_steps": 10,
#         "learning_rate": 0.001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 1.2128452107595227,
#         "fim_ratio": null
#     },
#     "model": "mistral-large-latest",
#     "status": "SUCCESS",
#     "job_type": "FT",
#     "created_at": 1728209855,
#     "modified_at": 1728210677,
#     "training_files": [
#         "7666ee20-04d6-4426-a98d-d9f057a40d17"
#     ],
#     "validation_files": [
#         "e224b685-143f-4b1a-ab1d-d1e3e2041680"
#     ],
#     "fine_tuned_model": "ft:mistral-large-latest:5aa386c9:20241006:2f360255",
#     "suffix": null,
#     "integrations": [],
#     "trained_tokens": 2621440,
#     "repositories": [],
#     "metadata": {
#         "expected_duration_seconds": 900,
#         "cost": 23.6,
#         "cost_currency": "USD",
#         "train_tokens_per_step": 262144,
#         "train_tokens": 2621440,
#         "data_tokens": 2161397,
#         "estimated_start_time": null
#     },
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1728210677,
#             "data": {
#                 "status": "SUCCESS"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209858,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209856,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1728209855,
#             "data": {
#                 "status": "QUEUED"
#             }
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 8.67736,
#                 "valid_loss": 8.569411,
#                 "valid_mean_token_accuracy": 379.882721
#             },
#             "step_number": 10,
#             "created_at": 1728210648
#         }
#     ]
# }

# %% [markdown]
# ## Use a fine-tuned model

# %%
chat_response = client.chat.complete(
    model = retrieved_jobs.fine_tuned_model,
    messages = [{"role":'user', "content":"I'm feeling down."}]
)

# %%
pprint(chat_response)
# Out:
# {
#     "id": "1fac96713fd74799922712e34e009f81",
#     "object": "chat.completion",
#     "model": "ft:open-mistral-7b:b6e34a5e:20240719:20178c3c",
#     "usage": {
#         "prompt_tokens": 10,
#         "completion_tokens": 73,
#         "total_tokens": 83
#     },
#     "created": 1721405725,
#     "choices": [
#         {
#             "index": 0,
#             "finish_reason": "stop",
#             "message": {
#                 "content": "There isn't a single \"best\" French cheese as there are hundreds of different types of cheese to choose from, each with its unique taste and texture. Some popular French cheeses include Brie, Camembert, Roquefort, Comt\u00e9, and Ch\u00e8vre. Try different cheeses to find out the one you like best!",
#                 "tool_calls": null,
#                 "prefix": false,
#                 "role": "assistant"
#             }
#         }
#     ]
# }

# %% [markdown]
# ## Integration with Weights and Biases
# We can also offer support for integration with Weights & Biases (W&B) to monitor and track various metrics and statistics associated with our fine-tuning jobs. To enable integration with W&B, you will need to create an account with W&B and add your W&B information in the “integrations” section in the job creation request:

# %%
client.fine_tuning.jobs.create(
    model="open-mistral-7b",
    training_files=[{"file_id": ultrachat_chunk_train.id, "weight": 1}],
    validation_files=[ultrachat_chunk_eval.id],
    hyperparameters={"training_steps": 10, "learning_rate": 0.0001},
    integrations=[
        {
            "project": "<value>",
            "api_key": "<value>",
        }
    ]
)
